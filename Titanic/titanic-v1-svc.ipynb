# %%
import pandas as pd
import os
import seaborn as sns

os.getcwd()
all_data = pd.read_csv('input/train.csv')
all_data['relatives'] = all_data['SibSp'] + all_data['Parch']

# %%
all_data_x = all_data.drop(['Survived', 'PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
all_data_y = all_data['Survived']
all_data_y.shape
# Out:
# (891,)

# %%
#test below 20 removes a column in test!!
from sklearn.model_selection import train_test_split
x_train, x_test, y_train_prepared, y_test_prepared = train_test_split(all_data_x, all_data_y, test_size=0.18)

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('std_sclare', StandardScaler())
])

num_attribs = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'relatives']
cat_attribs = ['Sex', 'Embarked']
full_pipeline = ColumnTransformer([
        ('num', num_pipeline, num_attribs),
        ('cat', OneHotEncoder(), cat_attribs)
])

x_train_prepared = full_pipeline.fit_transform(x_train)
x_test_prepared = full_pipeline.fit_transform(x_test)

y_train_survived = (y_train_prepared == 1)

from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

def plot_roc_curve(fpr, tpr, decoration, label=None):
    plt.plot(fpr, tpr, decoration, linewidth=2, label=label)
    plt.plot( [0, 1], [0, 1], 'k--')

from sklearn.model_selection import cross_val_predict
from sklearn.svm import SVC

svm_clf = SVC()
svm_clf.fit(x_train_prepared, y_train_survived)
y_scores_svm = cross_val_predict(svm_clf, x_train_prepared, y_train_survived, cv=10, method='decision_function')
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_train_survived, y_scores_svm)

plot_roc_curve(fpr_svm, tpr_svm, 'r--', "Support Vector Machine rbf")
plt.legend(loc="lower right")
plt.show()

# %%
x_test_prepared.shape
# Out:
# (161, 12)

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold

# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'C': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000], 'gamma': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000], 'gamma': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]}]

scores = ['precision', 'recall', 'roc_auc']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv = StratifiedKFold(), scoring=score) #scoring='%s_macro' % score)
    clf.fit(x_train_prepared, y_train_prepared)

    print("# Tuning hyper-parameters for %s" % score)
    print()
    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test_prepared, clf.predict(x_test_prepared)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
#   _warn_prf(average, modifier, msg_start, len(result))
#
# /home/toussaint/Documents/projets_rl/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#
# ...
#
# 0.667 (+/-0.131) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.698 (+/-0.112) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.653 (+/-0.090) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.551 (+/-0.463) for {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.186 (+/-0.131) for {'C': 1, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.095 (+/-0.048) for {'C': 1, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.186 (+/-0.090) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.667 (+/-0.113) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.663 (+/-0.124) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.642 (+/-0.093) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.684 (+/-0.142) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.533 (+/-0.424) for {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.214 (+/-0.103) for {'C': 10, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.091 (+/-0.041) for {'C': 10, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.667 (+/-0.113) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.660 (+/-0.127) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.695 (+/-0.121) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.635 (+/-0.084) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.646 (+/-0.146) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.474 (+/-0.383) for {'C': 100, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.218 (+/-0.103) for {'C': 100, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.091 (+/-0.041) for {'C': 100, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.667 (+/-0.113) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.667 (+/-0.127) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.642 (+/-0.103) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.653 (+/-0.120) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.554 (+/-0.151) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.375 (+/-0.194) for {'C': 1000, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.218 (+/-0.076) for {'C': 1000, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.091 (+/-0.041) for {'C': 1000, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.000 (+/-0.000) for {'C': 0.0001, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.000 (+/-0.000) for {'C': 0.0001, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.000 (+/-0.000) for {'C': 0.0001, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.000 (+/-0.000) for {'C': 0.0001, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.000 (+/-0.000) for {'C': 0.0001, 'gamma': 1, 'kernel': 'linear'}
#
# 0.000 (+/-0.000) for {'C': 0.0001, 'gamma': 10, 'kernel': 'linear'}
#
# 0.000 (+/-0.000) for {'C': 0.0001, 'gamma': 100, 'kernel': 'linear'}
#
# 0.000 (+/-0.000) for {'C': 0.0001, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.011 (+/-0.017) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.011 (+/-0.017) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.011 (+/-0.017) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.011 (+/-0.017) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.011 (+/-0.017) for {'C': 0.001, 'gamma': 1, 'kernel': 'linear'}
#
# 0.011 (+/-0.017) for {'C': 0.001, 'gamma': 10, 'kernel': 'linear'}
#
# 0.011 (+/-0.017) for {'C': 0.001, 'gamma': 100, 'kernel': 'linear'}
#
# 0.011 (+/-0.017) for {'C': 0.001, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.667 (+/-0.140) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.667 (+/-0.140) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.667 (+/-0.140) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.667 (+/-0.140) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.667 (+/-0.140) for {'C': 0.01, 'gamma': 1, 'kernel': 'linear'}
#
# 0.667 (+/-0.140) for {'C': 0.01, 'gamma': 10, 'kernel': 'linear'}
#
# 0.667 (+/-0.140) for {'C': 0.01, 'gamma': 100, 'kernel': 'linear'}
#
# 0.667 (+/-0.140) for {'C': 0.01, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.663 (+/-0.124) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.663 (+/-0.124) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.663 (+/-0.124) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.663 (+/-0.124) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.663 (+/-0.124) for {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
#
# 0.663 (+/-0.124) for {'C': 0.1, 'gamma': 10, 'kernel': 'linear'}
#
# 0.663 (+/-0.124) for {'C': 0.1, 'gamma': 100, 'kernel': 'linear'}
#
# 0.663 (+/-0.124) for {'C': 0.1, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1, 'gamma': 1, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1, 'gamma': 10, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1, 'gamma': 100, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 10, 'gamma': 1, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 10, 'gamma': 10, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 10, 'gamma': 100, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 10, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 100, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 100, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 100, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 100, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 100, 'gamma': 1, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 100, 'gamma': 10, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 100, 'gamma': 100, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 100, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1000, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1000, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1000, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1000, 'gamma': 1, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1000, 'gamma': 10, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1000, 'gamma': 100, 'kernel': 'linear'}
#
# 0.667 (+/-0.113) for {'C': 1000, 'gamma': 1000, 'kernel': 'linear'}
#
#
#
# Detailed classification report:
#
#
#
# The model is trained on the full development set.
#
# The scores are computed on the full evaluation set.
#
#
#
#               precision    recall  f1-score   support
#
#
#
#            0       0.89      0.92      0.91       104
#
#            1       0.85      0.79      0.82        57
#
#
#
#     accuracy                           0.88       161
#
#    macro avg       0.87      0.86      0.86       161
#
# weighted avg       0.87      0.88      0.87       161
#
#
#
#
#
# # Tuning hyper-parameters for roc_auc
#
#
# # Tuning hyper-parameters for roc_auc
#
#
#
# Best parameters set found on development set:
#
#
#
# {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
#
#
#
# Grid scores on development set:
#
#
#
# 0.829 (+/-0.051) for {'C': 0.0001, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.829 (+/-0.050) for {'C': 0.0001, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.836 (+/-0.050) for {'C': 0.0001, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.845 (+/-0.053) for {'C': 0.0001, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.827 (+/-0.029) for {'C': 0.0001, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.802 (+/-0.029) for {'C': 0.0001, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.767 (+/-0.035) for {'C': 0.0001, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.712 (+/-0.049) for {'C': 0.0001, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.829 (+/-0.051) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.829 (+/-0.050) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.835 (+/-0.049) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.845 (+/-0.053) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.825 (+/-0.028) for {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.801 (+/-0.028) for {'C': 0.001, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.769 (+/-0.039) for {'C': 0.001, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.715 (+/-0.050) for {'C': 0.001, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.829 (+/-0.051) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.829 (+/-0.052) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.834 (+/-0.048) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.845 (+/-0.052) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.826 (+/-0.034) for {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.802 (+/-0.031) for {'C': 0.01, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.766 (+/-0.030) for {'C': 0.01, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.730 (+/-0.030) for {'C': 0.01, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.826 (+/-0.051) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.829 (+/-0.049) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.833 (+/-0.047) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.844 (+/-0.049) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.826 (+/-0.033) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.801 (+/-0.035) for {'C': 0.1, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.769 (+/-0.034) for {'C': 0.1, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.731 (+/-0.033) for {'C': 0.1, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.827 (+/-0.050) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.831 (+/-0.049) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.852 (+/-0.050) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.835 (+/-0.035) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.801 (+/-0.036) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.790 (+/-0.045) for {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.767 (+/-0.031) for {'C': 1, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.730 (+/-0.033) for {'C': 1, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.832 (+/-0.048) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.845 (+/-0.065) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.833 (+/-0.057) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.808 (+/-0.070) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.787 (+/-0.054) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.767 (+/-0.057) for {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.760 (+/-0.030) for {'C': 10, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.712 (+/-0.027) for {'C': 10, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.842 (+/-0.064) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.842 (+/-0.054) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.837 (+/-0.057) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.791 (+/-0.058) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.772 (+/-0.049) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.769 (+/-0.049) for {'C': 100, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.756 (+/-0.019) for {'C': 100, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.701 (+/-0.037) for {'C': 100, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.833 (+/-0.068) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# 0.833 (+/-0.053) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#
# 0.825 (+/-0.063) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
#
# 0.774 (+/-0.112) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
#
# 0.749 (+/-0.058) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
#
# 0.749 (+/-0.060) for {'C': 1000, 'gamma': 10, 'kernel': 'rbf'}
#
# 0.748 (+/-0.022) for {'C': 1000, 'gamma': 100, 'kernel': 'rbf'}
#
# 0.700 (+/-0.041) for {'C': 1000, 'gamma': 1000, 'kernel': 'rbf'}
#
# 0.827 (+/-0.050) for {'C': 0.0001, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.827 (+/-0.050) for {'C': 0.0001, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.827 (+/-0.050) for {'C': 0.0001, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.827 (+/-0.050) for {'C': 0.0001, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.827 (+/-0.050) for {'C': 0.0001, 'gamma': 1, 'kernel': 'linear'}
#
# 0.827 (+/-0.050) for {'C': 0.0001, 'gamma': 10, 'kernel': 'linear'}
#
# 0.827 (+/-0.050) for {'C': 0.0001, 'gamma': 100, 'kernel': 'linear'}
#
# 0.827 (+/-0.050) for {'C': 0.0001, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.827 (+/-0.049) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.827 (+/-0.049) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.827 (+/-0.049) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.827 (+/-0.049) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.827 (+/-0.049) for {'C': 0.001, 'gamma': 1, 'kernel': 'linear'}
#
# 0.827 (+/-0.049) for {'C': 0.001, 'gamma': 10, 'kernel': 'linear'}
#
# 0.827 (+/-0.049) for {'C': 0.001, 'gamma': 100, 'kernel': 'linear'}
#
# 0.827 (+/-0.049) for {'C': 0.001, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.846 (+/-0.052) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.846 (+/-0.052) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.846 (+/-0.052) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.846 (+/-0.052) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.846 (+/-0.052) for {'C': 0.01, 'gamma': 1, 'kernel': 'linear'}
#
# 0.846 (+/-0.052) for {'C': 0.01, 'gamma': 10, 'kernel': 'linear'}
#
# 0.846 (+/-0.052) for {'C': 0.01, 'gamma': 100, 'kernel': 'linear'}
#
# 0.846 (+/-0.052) for {'C': 0.01, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.807 (+/-0.065) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.807 (+/-0.065) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.807 (+/-0.065) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.807 (+/-0.065) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.807 (+/-0.065) for {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
#
# 0.807 (+/-0.065) for {'C': 0.1, 'gamma': 10, 'kernel': 'linear'}
#
# 0.807 (+/-0.065) for {'C': 0.1, 'gamma': 100, 'kernel': 'linear'}
#
# 0.807 (+/-0.065) for {'C': 0.1, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.802 (+/-0.063) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.802 (+/-0.063) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.802 (+/-0.063) for {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.802 (+/-0.063) for {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.802 (+/-0.063) for {'C': 1, 'gamma': 1, 'kernel': 'linear'}
#
# 0.802 (+/-0.063) for {'C': 1, 'gamma': 10, 'kernel': 'linear'}
#
# 0.802 (+/-0.063) for {'C': 1, 'gamma': 100, 'kernel': 'linear'}
#
# 0.802 (+/-0.063) for {'C': 1, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.798 (+/-0.081) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.798 (+/-0.081) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.798 (+/-0.081) for {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.798 (+/-0.081) for {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.798 (+/-0.081) for {'C': 10, 'gamma': 1, 'kernel': 'linear'}
#
# 0.798 (+/-0.081) for {'C': 10, 'gamma': 10, 'kernel': 'linear'}
#
# 0.798 (+/-0.081) for {'C': 10, 'gamma': 100, 'kernel': 'linear'}
#
# 0.798 (+/-0.081) for {'C': 10, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.793 (+/-0.075) for {'C': 100, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.793 (+/-0.075) for {'C': 100, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.793 (+/-0.075) for {'C': 100, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.793 (+/-0.075) for {'C': 100, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.793 (+/-0.075) for {'C': 100, 'gamma': 1, 'kernel': 'linear'}
#
# 0.793 (+/-0.075) for {'C': 100, 'gamma': 10, 'kernel': 'linear'}
#
# 0.793 (+/-0.075) for {'C': 100, 'gamma': 100, 'kernel': 'linear'}
#
# 0.793 (+/-0.075) for {'C': 100, 'gamma': 1000, 'kernel': 'linear'}
#
# 0.825 (+/-0.064) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'linear'}
#
# 0.825 (+/-0.064) for {'C': 1000, 'gamma': 0.001, 'kernel': 'linear'}
#
# 0.825 (+/-0.064) for {'C': 1000, 'gamma': 0.01, 'kernel': 'linear'}
#
# 0.825 (+/-0.064) for {'C': 1000, 'gamma': 0.1, 'kernel': 'linear'}
#
# 0.825 (+/-0.064) for {'C': 1000, 'gamma': 1, 'kernel': 'linear'}
#
# 0.825 (+/-0.064) for {'C': 1000, 'gamma': 10, 'kernel': 'linear'}
#
# 0.825 (+/-0.064) for {'C': 1000, 'gamma': 100, 'kernel': 'linear'}
#
# 0.825 (+/-0.064) for {'C': 1000, 'gamma': 1000, 'kernel': 'linear'}
#
#
#
# Detailed classification report:
#
#
#
# The model is trained on the full development set.
#
# The scores are computed on the full evaluation set.
#
#
#
#               precision    recall  f1-score   support
#
#
#
#            0       0.86      0.92      0.89       104
#
#            1       0.84      0.74      0.79        57
#
#
#
#     accuracy                           0.86       161
#
#    macro avg       0.85      0.83      0.84       161
#
# weighted avg       0.86      0.86      0.85       161
